# %%
import pandas as pd

# %%
df = pd.read_csv('sales_data_sample.csv',encoding='latin1')

# %%
df.head()
# Out:
#    ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0        10107               30      95.70                2  2871.00
# 1        10121               34      81.35                5  2765.90
# 2        10134               41      94.74                2  3884.34
# 3        10145               45      83.26                6  3746.70
# 4        10159               49     100.00               14  5205.27
#
#          ORDERDATE   STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# 0   2/24/2003 0:00  Shipped       1         2     2003  ...
# 1    5/7/2003 0:00  Shipped       2         5     2003  ...
# 2    7/1/2003 0:00  Shipped       3         7     2003  ...
# 3   8/25/2003 0:00  Shipped       3         8     2003  ...
# 4  10/10/2003 0:00  Shipped       4        10     2003  ...
#
#                     ADDRESSLINE1  ADDRESSLINE2           CITY STATE  \
# 0        897 Long Airport Avenue           NaN            NYC    NY
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2823 entries, 0 to 2822
# Data columns (total 25 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ORDERNUMBER       2823 non-null   int64
#  1   QUANTITYORDERED   2823 non-null   int64
#  2   PRICEEACH         2823 non-null   float64
#  3   ORDERLINENUMBER   2823 non-null   int64
#  4   SALES             2823 non-null   float64
#  5   ORDERDATE         2823 non-null   object
#  6   STATUS            2823 non-null   object
#  7   QTR_ID            2823 non-null   int64
#  8   MONTH_ID          2823 non-null   int64
#  9   YEAR_ID           2823 non-null   int64
#  10  PRODUCTLINE       2823 non-null   object
#  11  MSRP              2823 non-null   int64
#  12  PRODUCTCODE       2823 non-null   object
#  13  CUSTOMERNAME      2823 non-null   object
#  14  PHONE             2823 non-null   object
#  15  ADDRESSLINE1      2823 non-null   object
# ...

# %%
df = df.drop(columns=['ORDERNUMBER','ORDERDATE','ADDRESSLINE1','ADDRESSLINE2','CONTACTLASTNAME','CONTACTFIRSTNAME','CUSTOMERNAME','PHONE'])

# %%
df
# Out:
#       QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES    STATUS  QTR_ID  \
# 0                  30      95.70                2  2871.00   Shipped       1
# 1                  34      81.35                5  2765.90   Shipped       2
# 2                  41      94.74                2  3884.34   Shipped       3
# 3                  45      83.26                6  3746.70   Shipped       3
# 4                  49     100.00               14  5205.27   Shipped       4
# ...               ...        ...              ...      ...       ...     ...
# 2818               20     100.00               15  2244.40   Shipped       4
# 2819               29     100.00                1  3978.51   Shipped       1
# 2820               43     100.00                4  5417.57  Resolved       1
# 2821               34      62.24                1  2116.16   Shipped       1
# 2822               47      65.52                9  3079.44   On Hold       2
#
# ...

# %%
df.isnull().sum()
# Out:
# QUANTITYORDERED       0
# PRICEEACH             0
# ORDERLINENUMBER       0
# SALES                 0
# STATUS                0
# QTR_ID                0
# MONTH_ID              0
# YEAR_ID               0
# PRODUCTLINE           0
# MSRP                  0
# PRODUCTCODE           0
# CITY                  0
# STATE              1486
# POSTALCODE           76
# COUNTRY               0
# TERRITORY          1074
# DEALSIZE              0
# dtype: int64

# %%
df.drop(columns=['STATE','POSTALCODE','TERRITORY','QTR_ID','MONTH_ID'],inplace=True)

# %%
df
# Out:
#       QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES    STATUS  YEAR_ID  \
# 0                  30      95.70                2  2871.00   Shipped     2003
# 1                  34      81.35                5  2765.90   Shipped     2003
# 2                  41      94.74                2  3884.34   Shipped     2003
# 3                  45      83.26                6  3746.70   Shipped     2003
# 4                  49     100.00               14  5205.27   Shipped     2003
# ...               ...        ...              ...      ...       ...      ...
# 2818               20     100.00               15  2244.40   Shipped     2004
# 2819               29     100.00                1  3978.51   Shipped     2005
# 2820               43     100.00                4  5417.57  Resolved     2005
# 2821               34      62.24                1  2116.16   Shipped     2005
# 2822               47      65.52                9  3079.44   On Hold     2005
#
# ...

# %%
df.duplicated().sum()
# Out:
# 0

# %%
from sklearn.preprocessing import LabelEncoder
en = LabelEncoder()

# %%
df['STATUS'] = en.fit_transform(df['STATUS'])
df['PRODUCTLINE'] = en.fit_transform(df['PRODUCTLINE'])
df['PRODUCTCODE'] = en.fit_transform(df['PRODUCTCODE'])
df['CITY'] = en.fit_transform(df['CITY'])
df['COUNTRY'] = en.fit_transform(df['COUNTRY'])
df['DEALSIZE'] = en.fit_transform(df['DEALSIZE'])

# %%
df.head()
# Out:
#    QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  STATUS  YEAR_ID  \
# 0               30      95.70                2  2871.00       5     2003
# 1               34      81.35                5  2765.90       5     2003
# 2               41      94.74                2  3884.34       5     2003
# 3               45      83.26                6  3746.70       5     2003
# 4               49     100.00               14  5205.27       5     2003
#
#    PRODUCTLINE  MSRP  PRODUCTCODE  CITY  COUNTRY  DEALSIZE
# 0            1    95            0    42       18         2
# 1            1    95            0    56        6         2
# 2            1    95            0    52        6         1
# 3            1    95            0    53       18         1
# 4            1    95            0    59       18         1

# %%
from sklearn.cluster import KMeans
wcss = []
for i in range(1,21):
    km = KMeans(n_clusters=i)
    km.fit_predict(df)
    wcss.append(km.inertia_)

# %%
wcss
# Out:
# [9583577380.125648,
#  3329699153.7340655,
#  1736386268.6190326,
#  1046926762.0488263,
#  719224891.5528121,
#  518487068.42707163,
#  400207885.72837985,
#  301950215.9646298,
#  237837690.64465362,
#  194713763.2434765,
#  163951022.18092322,
#  139442100.8474025,
#  120176588.80387673,
#  102860970.92857616,
#  93202546.28916506,
#  83311000.29180731,
#  79621302.19342792,
#  69781266.19711417,
#  63955332.10671877,
#  57507238.01768574]

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(wcss)

# %%
km = KMeans(n_clusters=4)
pred = km.fit_predict(df)

# %%
df['label'] = pred

# %%
df.head()
# Out:
#    QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  STATUS  YEAR_ID  \
# 0               30      95.70                2  2871.00       5     2003
# 1               34      81.35                5  2765.90       5     2003
# 2               41      94.74                2  3884.34       5     2003
# 3               45      83.26                6  3746.70       5     2003
# 4               49     100.00               14  5205.27       5     2003
#
#    PRODUCTLINE  MSRP  PRODUCTCODE  CITY  COUNTRY  DEALSIZE  label
# 0            1    95            0    42       18         2      2
# 1            1    95            0    56        6         2      2
# 2            1    95            0    52        6         1      2
# 3            1    95            0    53       18         1      2
# 4            1    95            0    59       18         1      1

# %%
# K-Means Clustering: This is a method used to group data points into clusters (or groups) based on their similarities. You start by picking a number of clusters (K), and the algorithm divides the data into K clusters so that points within each cluster are close to each other. The goal is to minimize the distance between data points and the center (mean) of their cluster, hence "K-Means."

# Hierarchical Clustering: This is another way to group data into clusters, but it builds a hierarchy (a tree) of clusters. It starts with each data point as its own cluster and then gradually merges the closest clusters together, one at a time, until everything is in one big cluster. This method helps show how data points are grouped at different levels.

# Elbow Method: The elbow method helps find the best number of clusters (K) to use in K-means. It involves running K-means for different values of K (e.g., from 1 to 10) and plotting the "Within-Cluster Sum of Squares" (WCSS), which measures how tight the clusters are. As K increases, WCSS decreases, but at a certain point (the "elbow"), the improvement slows down. The "elbow" point suggests an ideal number of clusters.
